# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("fast")

# %% [markdown]
# **This file has the exploratory data analysis graphs.
# The input here is the clean data set that can be found in the main code.**

# %%
data_2=pd.read_csv("/Users/riddhimab/Desktop/Duke/Data Science Proj/new_df.csv")

# %%
data_2.head()
# Out:
#    Unnamed: 0  TARGET NAME_CONTRACT_TYPE  CODE_GENDER_M  FLAG_OWN_CAR  \
# 0           0       1         Cash loans              1             0
# 1           2       0    Revolving loans              1             1
# 2           5       0         Cash loans              1             0
# 3           6       0         Cash loans              0             1
# 4           7       0         Cash loans              1             1
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_current  \
# 0                1             0          202500.0            406597.5
# 1                1             0           67500.0            135000.0
# 2                1             0           99000.0            490495.5
# 3                1             1          171000.0           1560726.0
# 4                1             0          360000.0           1530000.0
#
#    AMT_GOODS_PRICE  ... AMT_REQ_CREDIT_BUREAU_DAY AMT_REQ_CREDIT_BUREAU_WEEK  \
# ...

# %%
## Printing the correlation matrix
cormat2 = data_2.corr()
round(cormat2,2)
# Out:
#                              Unnamed: 0  TARGET  CODE_GENDER_M  FLAG_OWN_CAR  \
# Unnamed: 0                         1.00   -0.00          -0.00          0.00
# TARGET                            -0.00    1.00           0.04         -0.03
# CODE_GENDER_M                     -0.00    0.04           1.00          0.34
# FLAG_OWN_CAR                       0.00   -0.03           0.34          1.00
# FLAG_OWN_REALTY                   -0.00   -0.00          -0.04          0.01
# CNT_CHILDREN                      -0.00    0.01           0.01          0.07
# AMT_INCOME_TOTAL                  -0.00   -0.00           0.06          0.06
# AMT_CREDIT_current                -0.00   -0.04           0.01          0.10
# AMT_GOODS_PRICE                   -0.00   -0.05           0.01          0.10
# REGION_POPULATION_RELATIVE         0.00   -0.04           0.02          0.04
# AGE                                0.00   -0.07          -0.07         -0.05
# ...

# %%
##Making the correlation plot
ax=sns.heatmap(cormat2)
sns.color_palette("flare", as_cmap=True)
ax.set_xticklabels(
    ax.get_xticklabels())
# Out:
# [Text(0.5, 0, 'Unnamed: 0'),
#  Text(2.5, 0, 'CODE_GENDER_M'),
#  Text(4.5, 0, 'FLAG_OWN_REALTY'),
#  Text(6.5, 0, 'AMT_INCOME_TOTAL'),
#  Text(8.5, 0, 'AMT_GOODS_PRICE'),
#  Text(10.5, 0, 'AGE'),
#  Text(12.5, 0, 'DAYS_REGISTRATION'),
#  Text(14.5, 0, 'FLAG_EMP_PHONE'),
#  Text(16.5, 0, 'FLAG_CONT_MOBILE'),
#  Text(18.5, 0, 'FLAG_EMAIL'),
#  Text(20.5, 0, 'REGION_RATING_CLIENT_W_CITY'),
#  Text(22.5, 0, 'REG_REGION_NOT_LIVE_REGION'),
#  Text(24.5, 0, 'LIVE_REGION_NOT_WORK_REGION'),
#  Text(26.5, 0, 'REG_CITY_NOT_WORK_CITY'),
#  Text(28.5, 0, 'EXT_SOURCE_2'),
#  Text(30.5, 0, 'OBS_30_CNT_SOCIAL_CIRCLE'),
#  Text(32.5, 0, 'OBS_60_CNT_SOCIAL_CIRCLE'),
#  Text(34.5, 0, 'DAYS_LAST_PHONE_CHANGE'),
#  Text(36.5, 0, 'AMT_REQ_CREDIT_BUREAU_DAY'),
#  Text(38.5, 0, 'AMT_REQ_CREDIT_BUREAU_MON'),
#  Text(40.5, 0, 'AMT_REQ_CREDIT_BUREAU_YEAR')]

# %%
## Creating a list of categorical variables.
categorical = list(set(data_2.columns) - set(data_2.describe().columns))
categorical
# Out:
# ['NAME_INCOME_TYPE',
#  'WEEKDAY_APPR_PROCESS_START',
#  'NAME_YIELD_GROUP',
#  'NAME_HOUSING_TYPE',
#  'ORGANIZATION_TYPE',
#  'NAME_CONTRACT_TYPE',
#  'OCCUPATION_TYPE',
#  'CODE_REJECT_REASON',
#  'NAME_TYPE_SUITE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_CONTRACT_STATUS',
#  'NAME_CASH_LOAN_PURPOSE',
#  'NAME_FAMILY_STATUS']

# %%
## Making a histogram for all the categorical variables.
plot.figure()
for i in categorical:
    sns.countplot(data_2[i])
    plot.xticks(rotation=90)
    print(plot.show())
# Out:
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# None
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# None
# ...

# %% [markdown]
# **Cleaning up the plots and adding labels for the visualizations we want to keep.**

# %%
## Adding labels to the plot
plt.figure()
x=sns.countplot(data_2["OCCUPATION_TYPE"])
plt.xticks(rotation=90)
plt.title('Figure 1: Histogram of Type of Occupation of Applicant')
x.set(xlabel='Occupation of Applicant')
plt.show()
sns_plot.savefig("/Users/riddhimab/Desktop/Duke/Data Science Proj/Fig1.png")
# Out:
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/50/5tsnv4tj7kl1vz673t824p0w0000gn/T/ipykernel_27208/2653104208.py in <module>
#       5 x.set(xlabel='Occupation of Applicant')
#       6 plt.show()
# ----> 7 sns_plot.savefig("/Users/riddhimab/Desktop/Duke/Data Science Proj/Fig1.png")
#
# NameError: name 'sns_plot' is not defined

# %%
## Adding labels to the plot
plt.figure()
x=sns.countplot(data_2["NAME_CONTRACT_STATUS"])
plt.xticks(rotation=90)
plt.title('Figure 2: Histogram of The Individuals Previous Loan Status')
x.set(xlabel='Previous Loan Status')
plt.show()
# Out:
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
## Adding labels to the plot
plt.figure()
x=sns.countplot(data_2["NAME_CONTRACT_TYPE"])
plt.title('Figure 3: Histogram of The Type of Loan')
x.set(xlabel='Type of Loan')
plt.show()
# Out:
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
## Adding labels to the plot
plt.figure()
x=sns.countplot(data_2["NAME_EDUCATION_TYPE"])
plt.xticks(rotation=90)
plt.title('Figure 4: Histogram of The Education Level of Applicants')
x.set(xlabel='Education Level')
plt.show()
# Out:
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating a list of numerical columns

numerical= list(set(data_2.describe().columns))
numerical
# Out:
# ['DAYS_LAST_PHONE_CHANGE',
#  'REGION_POPULATION_RELATIVE',
#  'AMT_INCOME_TOTAL',
#  'REG_CITY_NOT_WORK_CITY',
#  'EXT_SOURCE_2',
#  'OBS_60_CNT_SOCIAL_CIRCLE',
#  'AMT_GOODS_PRICE',
#  'FLAG_EMAIL',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'YEARS_EXP',
#  'Unnamed: 0',
#  'CODE_GENDER_M',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'FLAG_OWN_CAR',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'EXT_SOURCE_3',
#  'AMT_REQ_CREDIT_BUREAU_MON',
#  'REG_REGION_NOT_LIVE_REGION',
#  'DAYS_REGISTRATION',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'FLAG_CONT_MOBILE',
#  'REGION_RATING_CLIENT_W_CITY',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'AMT_CREDIT_previous',
#  'REG_CITY_NOT_LIVE_CITY',
#  'AMT_REQ_CREDIT_BUREAU_YEAR',
#  'AMT_REQ_CREDIT_BUREAU_DAY',
#  'DAYS_ID_PUBLISH',
#  'AMT_CREDIT_current',
#  'FLAG_WORK_PHONE',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'AMT_REQ_CREDIT_BUREAU_HOUR',
#  'HOUR_APPR_PROCESS_START',
#  'REG_REGION_NOT_WORK_REGION',
#  'AGE',
#  'FLAG_EMP_PHONE',
#  'FLAG_PHONE',
#  'TARGET',
# ...

# %%
# plotting graph for all the numerical columns:

plot.figure()
for i in numerical:
    sns.distplot(data_2[i])
    plot.xticks(rotation=90)
    print(plot.show())
# Out:
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# None
# /Users/riddhimab/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# None
# ...

# %%
# subsetting the data for defaulters and non defaulers

defaulter= data_2[data_2['TARGET']==1]
non_defaulter=data_2[data_2['TARGET']==0]

# %%
## getting the numerical data for defaulters
num_default=defaulter[numerical]

# %%
num_default.corr()
# Out:
#                              TARGET  AMT_REQ_CREDIT_BUREAU_YEAR  \
# TARGET                          NaN                         NaN
# AMT_REQ_CREDIT_BUREAU_YEAR      NaN                    1.000000
# REG_CITY_NOT_WORK_CITY          NaN                   -0.013550
# EXT_SOURCE_3                    NaN                   -0.055784
# REG_REGION_NOT_WORK_REGION      NaN                   -0.024996
# AMT_REQ_CREDIT_BUREAU_QRT       NaN                    0.103658
# FLAG_EMAIL                      NaN                    0.056768
# REG_CITY_NOT_LIVE_CITY          NaN                   -0.005359
# YEARS_EXP                       NaN                    0.015490
# DAYS_LAST_PHONE_CHANGE          NaN                   -0.095456
# EXT_SOURCE_2                    NaN                   -0.005866
# AMT_REQ_CREDIT_BUREAU_WEEK      NaN                    0.017491
# AGE                             NaN                    0.080191
# AMT_INCOME_TOTAL                NaN                   -0.000938
# ...

# %%
#Analyse Categorical variables with respect to Target variable

plot.figure(figsize = (20, 40))

plot.subplots_adjust(hspace=0.6)
for i in enumerate(categorical):
    plot.subplot(5, 2, i[0]+1)
    
    sns.countplot(x = i[1], hue = 'TARGET',  data = data_2)
   
    plot.xticks(rotation = 45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/50/5tsnv4tj7kl1vz673t824p0w0000gn/T/ipykernel_27208/736715885.py in <module>
#       5 plot.subplots_adjust(hspace=0.6)
#       6 for i in enumerate(categorical):
# ----> 7     plot.subplot(5, 2, i[0]+1)
#       8
#       9     sns.countplot(x = i[1], hue = 'TARGET',  data = data_2)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# ...

# %%
#Analyse Categorical variables with respect to Target variable

plt.figure()
x=sns.countplot(x = "OCCUPATION_TYPE", hue = 'TARGET',  data = data_2)
plot.xticks(rotation = 90)
plt.title('Figure 5: Plot of the Occupation Type for the Default Status')
x.set(xlabel='Occupation of Applicant') 
plt.show()

# %%
#Analyse Categorical variables with respect to Target variable

plt.figure()
x=sns.countplot(x = "NAME_CONTRACT_STATUS", hue = 'TARGET',  data = data_2)
plot.xticks(rotation = 90)
plt.title('Figure 6: Plot of the number of Defaulters Compared to the Previous Loan Status')
x.set(xlabel='Previous Loan Status for the Applicant') 
plt.show()

# %%
# Plot for Organization Type and Amount Goods Price divided by categories of default/no-default.

fig = plot.figure(figsize=(15,9))
plot.subplots_adjust(hspace=0.8)
plot.title('Organization Type and Income of Applicant compared with Default Status')
    
ax1 = plot.subplot(211)
a=sns.barplot(data= defaulter , x='ORGANIZATION_TYPE', y='AMT_INCOME_TOTAL',palette = "gist_rainbow" ,orient='v')
plot.xticks(rotation= 90)
plot.title('Defaulter')
a.set(xlabel="Oragnization Type of the Applicant", ylabel="Income of the Applicant")

ax2 = plot.subplot(212)
b=sns.barplot(data= non_defaulter , x='ORGANIZATION_TYPE', y='AMT_INCOME_TOTAL',palette = "gist_rainbow", orient='v')
plot.xticks(rotation= 90)
plot.title('Non-Defaulter')
b.set(xlabel="Oragnization Type of the Applicant", ylabel="Income of the Applicant")

fig.tight_layout()
plot.show()

# %%
# Plot for the AMT_INCOME_TOTAL vs NAME_FAMILY_STATUS

fig = plot.figure(figsize=(15,9))
plot.subplots_adjust(hspace=0.8)

ax1 = plot.subplot(211)
sns.barplot( x='NAME_FAMILY_STATUS' , y='AMT_INCOME_TOTAL',palette = "twilight_r",data= defaulter)
plot.xticks(rotation= 90)
plot.title('Defaulter')

ax2 = plot.subplot(212,sharex=ax1)
sns.barplot( x='NAME_FAMILY_STATUS', y= 'AMT_INCOME_TOTAL' ,palette = "twilight_r",data= non_defaulter )
plot.xticks(rotation= 90)
plot.title('Non-Defaulter')

fig.tight_layout()
plot.show()

# %%
#PLot for AMT_CREDIT vs CLIENT_AGE_GROUP

fig = plot.figure(figsize=(15,9))
plot.subplots_adjust(hspace=0.8)

ax1 = plot.subplot(211)
a=sns.barplot( x='AGE' , y='AMT_CREDIT_current', hue= "CODE_GENDER_M",palette = "Spectral_r",data= defaulter)
plot.xticks(rotation= 90)
plot.title('Defaulter')
a.set(xlabel="Age of the Applicant", ylabel="Loan Amount Requested")

ax2 = plot.subplot(212)
b=sns.barplot( x='AGE', y= 'AMT_CREDIT_current', hue= "CODE_GENDER_M", palette = "Spectral_r",data= non_defaulter )
plot.xticks(rotation= 90)
plot.title('Non-Defaulter')
b.set(xlabel="Age of the Applicant", ylabel="Loan Amount Requested")

fig.tight_layout()
plot.show()

# %%
#Plot for Previous Credit amount vs Loan Purpose

plot.figure(figsize=(30,18))
plot.rcParams["axes.labelsize"] = 25
plot.rcParams['axes.titlesize'] = 28
plot.rcParams['axes.titlepad'] = 30
plot.xticks(rotation=90)
plot.yscale('log')

sns.boxplot(data =data_2, x='NAME_CASH_LOAN_PURPOSE',hue='NAME_CONTRACT_STATUS',y='AMT_CREDIT_current',palette= 'nipy_spectral')
plot.title('Credit Amount vs Loan Purpose')
plot.show()

# %%
# Plot for Prev Credit amount  vs Housing type

plot.figure(figsize=(12,8))
plot.xticks(rotation=90)
sns.boxplot(data = data_2,x='NAME_HOUSING_TYPE', y='AMT_CREDIT_current',hue='TARGET')
plot.title('Prev Credit  vs Housing type')
plot.show()

# %%
pair_plot_cols=[
 'AMT_INCOME_TOTAL',
 'AMT_CREDIT_current',
 'AMT_GOODS_PRICE']
pair_df=pd.concat([data_2[pair_plot_cols],data_2["TARGET"]],axis=1)
sns.pairplot(pair_df,hue="TARGET")
plot.xticks(rotation= 90)
plot.yticks(rotation= 90)
# Out:
# (array([0.0e+00, 5.0e-07, 1.0e-06, 1.5e-06, 2.0e-06]),
#  [Text(1, 0, ''),
#   Text(1, 0, ''),
#   Text(1, 0, ''),
#   Text(1, 0, ''),
#   Text(1, 0, '')])

# %%
sns.pairplot(data_2)
